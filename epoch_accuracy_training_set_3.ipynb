# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
var = pd.read_excel('/Users/sgrgh/Desktop/code/Test1.xlsx')
print(var)
# Out:
#     Epochs1  Accuracy1  Accuracy2
# 0         1      46.55      46.81
# 1         2      46.55      46.81
# 2         3      51.72      51.06
# 3         4      46.55      74.47
# 4         5      46.55      82.98
# 5         6      46.55      82.98
# 6         7      47.41      87.23
# 7         8      65.52      85.11
# 8         9      68.97      87.23
# 9        10      81.90      87.23
# 10       11      73.28      87.23
# 11       12      90.52      90.52

# %%
x = list(var['Epochs1'])
y1 = list(var['Accuracy1'])
y2 = list(var['Accuracy2'])

# %%
plt.figure(figsize=(15,5), dpi =300)
plt.plot([str(i) for i in x], y1,y2, linestyle='dashed', marker='s')
plt.xlabel("Epochs", size = '10')
plt.ylabel("Accracy (%)",size = '10', )
plt.legend(['Train Ratio = 0.5' , 'Train Ratio = 0.8'], fontsize = 'large')
plt.show()
